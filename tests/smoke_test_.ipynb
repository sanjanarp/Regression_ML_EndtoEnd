# %%
import sys
from pathlib import Path

# Force notebook to recognize project root
import os
ROOT = Path(os.getcwd()).resolve().parents[0] # one level up from tests/
if str(ROOT) not in sys.path:
    sys.path.append(str(ROOT))

import pandas as pd
from src.inference_pipeline.inference import predict

# Load a few rows of already preprocessed data
sample_path = ROOT / "data/processed/cleaning_eval.csv"
df = pd.read_csv(sample_path).sample(5, random_state=42).reset_index(drop=True)

print("Input sample:")
display(df.head())

# Run inference
preds_df = predict(df)
print("✅ Predictions returned")
display(preds_df[["predicted_price"]].head())
# Out:
# 📂 Inference using project root: C:\Users\sanja\Regression_ML_EndtoEnd
# Input sample:
#          date  median_sale_price  median_list_price  median_ppsf  \
# 0  2021-07-31           258528.0           259900.0   145.396160
# 1  2021-08-31           457000.0           429000.0   253.164135
# 2  2020-02-29           187250.0           202500.0    99.965760
# 3  2020-06-30           517500.0           539900.0   217.805198
# 4  2021-07-31           749000.0           749400.0   349.226265
#
#    median_list_ppsf  homes_sold  pending_sales  new_listings  inventory  \
# 0        140.979244       104.0           98.0         107.0       66.0
# 1        257.973734        82.0           95.0         117.0      126.0
# 2        109.198464        94.0          115.0         140.0      157.0
# 3        217.108051         6.0           11.0          11.0       14.0
# 4        339.058053       113.0          112.0         140.0       60.0
#
#    median_dom  ...  Median Home Value  Total Labor Force  \
# 0        48.0  ...           182900.0            10937.0
# 1        71.0  ...                0.0                0.0
# 2        47.5  ...           161000.0            31265.0
# 3        68.0  ...           531100.0             1251.0
# 4        18.0  ...           591100.0            16826.0
#
#    Unemployed Population Total School Age Population  Total School Enrollment  \
# 0                  250.0                     20604.0                  20604.0
# 1                    0.0                         0.0                      0.0
# 2                 1746.0                     52357.0                  52357.0
# 3                   30.0                      1991.0                   1991.0
# 4                  681.0                     31591.0                  31591.0
#
#    Median Commute Time          price                         city_full  lat  \
# 0              10007.0  255300.562038                        cincinnati  NaN
# 1                  0.0  450603.296700       new york-newark-jersey city  NaN
# 2              27625.0  189474.969209    houston-pasadena-the woodlands  NaN
# 3               1156.0  504649.454265         baltimore-columbia-towson  NaN
# 4              14740.0  699558.033278  riverside-san bernardino-ontario  NaN
#
#    lng
# 0  NaN
# 1  NaN
# 2  NaN
# 3  NaN
# 4  NaN
#
# [5 rows x 41 columns]
# ⚠️ Skipping lat/lng merge: already present in DataFrame.
# ✅ Dropped 0 duplicate rows (excluding date/year).
# ✅ Removed 0 rows with median_list_price > 19M.
# C:\Users\sanja\AppData\Roaming\uv\python\cpython-3.11-windows-x86_64-none\Lib\pickle.py:1718: UserWarning: [17:29:48] WARNING: C:\actions-runner\_work\xgboost\xgboost\src\data\../common/error_msg.h:82: If you are loading a serialized model (like pickle in Python, RDS in R) or
# configuration generated by an older version of XGBoost, please export the model by calling
# `Booster.save_model` from that version first, then load it back in current version. See:
#
#     https://xgboost.readthedocs.io/en/stable/tutorials/saving_model.html
#
# for more details about differences between saving model and serializing.
#
#   setstate(state)
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[1], line 21
#      18 display(df.head())
#      20 # Run inference
# ---> 21 preds_df = predict(df)
#      22 print("✅ Predictions returned")
#      23 display(preds_df[["predicted_price"]].head())
#
# File ~\Regression_ML_EndtoEnd\src\inference_pipeline\inference.py:95, in predict(input_df, model_path, freq_encoder_path, target_encoder_path)
#      93 # Step 6: Load model & predict
#      94 model = load(model_path)
# ---> 95 preds = model.predict(df)
#      97 # Step 7: Build output
#      98 out = df.copy()
#
# File c:\Users\sanja\Regression_ML_EndtoEnd\.venv\Lib\site-packages\xgboost\core.py:729, in require_keyword_args.<locals>.throw_if.<locals>.inner_f(*args, **kwargs)
#     727 for k, arg in zip(sig.parameters, args):
#     728     kwargs[k] = arg
# --> 729 return func(**kwargs)
#
# File c:\Users\sanja\Regression_ML_EndtoEnd\.venv\Lib\site-packages\xgboost\sklearn.py:1327, in XGBModel.predict(self, X, output_margin, validate_features, base_margin, iteration_range)
#    1325 if self._can_use_inplace_predict():
#    1326     try:
# -> 1327         predts = self.get_booster().inplace_predict(
#    1328             data=X,
#    1329             iteration_range=iteration_range,
#    1330             predict_type="margin" if output_margin else "value",
#    1331             missing=self.missing,
#    1332             base_margin=base_margin,
#    1333             validate_features=validate_features,
#    1334         )
#    1335         if _is_cupy_alike(predts):
#    1336             cp = import_cupy()
#
# File c:\Users\sanja\Regression_ML_EndtoEnd\.venv\Lib\site-packages\xgboost\core.py:729, in require_keyword_args.<locals>.throw_if.<locals>.inner_f(*args, **kwargs)
#     727 for k, arg in zip(sig.parameters, args):
#     728     kwargs[k] = arg
# --> 729 return func(**kwargs)
#
# File c:\Users\sanja\Regression_ML_EndtoEnd\.venv\Lib\site-packages\xgboost\core.py:2667, in Booster.inplace_predict(self, data, iteration_range, predict_type, missing, validate_features, base_margin, strict_shape)
#    2665     data, fns, _ = _transform_pandas_df(data, enable_categorical)
#    2666     if validate_features:
# -> 2667         self._validate_features(fns)
#    2668 if _is_list(data) or _is_tuple(data):
#    2669     data = np.array(data)
#
# File c:\Users\sanja\Regression_ML_EndtoEnd\.venv\Lib\site-packages\xgboost\core.py:3243, in Booster._validate_features(self, feature_names)
#    3237 if my_missing:
#    3238     msg += (
#    3239         "\ntraining data did not have the following fields: "
#    3240         + ", ".join(str(s) for s in my_missing)
#    3241     )
# -> 3243 raise ValueError(msg.format(self.feature_names, feature_names))
#
# ValueError: feature_names mismatch: ['year', 'quarter', 'month', 'median_list_price', 'median_ppsf', 'median_list_ppsf', 'homes_sold', 'pending_sales', 'new_listings', 'inventory', 'median_dom', 'avg_sale_to_list', 'sold_above_list', 'off_market_in_two_weeks', 'bank', 'bus', 'hospital', 'mall', 'park', 'restaurant', 'school', 'station', 'supermarket', 'Total Population', 'Median Age', 'Per Capita Income', 'Total Families Below Poverty', 'Total Housing Units', 'Median Rent', 'Median Home Value', 'Total Labor Force', 'Unemployed Population', 'Total School Age Population', 'Total School Enrollment', 'Median Commute Time', 'lat', 'lng', 'zipcode_freq', 'city_encoded'] ['year', 'quarter', 'month', 'median_list_price', 'median_ppsf', 'median_list_ppsf', 'homes_sold', 'pending_sales', 'new_listings', 'inventory', 'median_dom', 'avg_sale_to_list', 'sold_above_list', 'off_market_in_two_weeks', 'bank', 'bus', 'hospital', 'mall', 'park', 'restaurant', 'school', 'station', 'supermarket', 'Total Population', 'Median Age', 'Per Capita Income', 'Total Families Below Poverty', 'Total Housing Units', 'Median Rent', 'Median Home Value', 'Total Labor Force', 'Unemployed Population', 'Total School Age Population', 'Total School Enrollment', 'Median Commute Time', 'lat', 'lng', 'zipcode_freq', 'city_full_encoded']
# expected city_encoded in input data
# training data did not have the following fields: city_full_encoded
